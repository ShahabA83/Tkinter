# %%
# Messagebox
messagebox.showinfo('showinfo', 'Show Info')

messagebox.showerror('showerror', 'Show Error')

messagebox.showwarning('showwarning', 'Show Warning')

messagebox.askquestion('askquestion', 'Ask Question')

messagebox.askokcancel("askokcancel", "Want to continue?")

# %%
# Messagebox
import tkinter
from tkinter import *
from tkinter import messagebox

window = Tk()
window.geometry('400x500')

messagebox.showinfo('showinfo', 'Show Info')

window.mainloop()

# %%
# Messagebox
from tkinter import *
from tkinter import messagebox

window = Tk()
window.geometry('400x500')

messagebox.showerror('showerror', 'Show Error')

window.mainloop()

# %%
# Messagebox
from tkinter import *
from tkinter import messagebox

window = Tk()
window.geometry('400x500')

messagebox.showwarning('showwarning', 'Show Warning')

window.mainloop()

# %%
# Messagebox
from tkinter import *
from tkinter import messagebox

window = Tk()
window.geometry('400x500')

messagebox.askquestion('askquestion', 'Ask Question')

window.mainloop()

# %%
# Messagebox
from tkinter import *
from tkinter import messagebox

window = Tk()
window.geometry('400x500')

messagebox.askokcancel("askokcancel", "Want to continue?")

window.mainloop()

# %%
# Messagebox
from tkinter import *
from tkinter import messagebox

window = Tk()
window.geometry('400x500')

def a():
    messagebox.showinfo('showinfo', 'Show Info')
def b():
    messagebox.showerror('showerror', 'Show Error')
def c():
    messagebox.showwarning('showwarning', 'Show Warning')
def d():
    messagebox.askquestion('askquestion', 'Ask Question')
def e():
    messagebox.askokcancel("askokcancel", "Want to continue?")

Button(text='Info', command=a).pack()
Button(text='Error', command=b).pack()
Button(text='Warning', command=c).pack()
Button(text='Question', command=d).pack()
Button(text='Canceli', command=e).pack()

window.mainloop()

# %%
# Messagebox
from tkinter import *
from tkinter import messagebox

window = Tk()
window.geometry('400x500')

x = messagebox.askquestion('askquestion', 'Ask Question')
print(x)

window.mainloop()
# Out:
# yes

# %%
# Messagebox
from tkinter import *
from tkinter import messagebox

window = Tk()
window.geometry('400x500')

x = messagebox.askokcancel("askokcancel", "Want to continue?")
print(x)

window.mainloop()
# Out:
# False

# %%
#تکرار بازی
from tkinter import *
import time
import random
from tkinter import messagebox

#---
flag = True

class ball:
    def __init__(self, canvas, paddle, color):
        
        self.canvas = canvas
        self.paddle = paddle
        self.id = canvas.create_oval(10,10,25,25, fill=color)
        self.canvas.move(self.id, 245, 100)
        starts = [-3,-2,-1,1,2,3]
        random.shuffle(starts)
        self.x = starts[0]
        self.y = -1
        self.height = 400
        self.width = 500

        self.hit_bottom = False
        
    def draw(self):
        global flag
        self.canvas.move(self.id, self.x, self.y)
        pos = self.canvas.coords(self.id)
        if pos[1] <= 0:
            self.y = 3

        if pos[3] >= self.height:
            self.hit_bottom = True
            #---
            x = messagebox.askokcancel("askokcancel", "Want to continue?")
            flag = x
                
            
        if self.hit_paddle(pos) == True:
            self.y = -3   
        if pos[0] <= 0:
            self.x = 3
        if pos[2] >= self.width:
            self.x = -3

    def hit_paddle(self, pos):
        paddle_pos = self.canvas.coords(self.paddle.id)
        if pos[2] >= paddle_pos[0] and pos[0] <= paddle_pos[2]:
            if pos[3] >=paddle_pos[1] and pos[3] <= paddle_pos[3]:
                return True
        return False

class paddle():
    def __init__(self, canvas, color):
        self.canvas = canvas
        self.id = canvas.create_rectangle(0,0,100,10, fill=color)
        self.canvas.move(self.id, 200, 300)
        self.x = 0
        self.width = 500
        self.canvas.bind_all('<KeyPress-Left>', self.turn_left)
        self.canvas.bind_all('<KeyPress-Right>', self.turn_right)
        
    def draw(self):
        pos = self.canvas.coords(self.id)
        if pos[0] <= 0 and self.x < 0:
            self.x = 0
        if pos[2] >= self.width and self.x > 0:
            self.x = 0
        self.canvas.move(self.id, self.x,0)
        
    def turn_left(self, evt):
        self.x = -2
        
    def turn_right(self, evt):
        self.x = 2
    


#----
while 1:
    window = Tk()
    window.title('Game')
    window.resizable(0,0)
    window.wm_attributes('-topmost', -1)
    cv = Canvas(window, width=500, height=400, bg='white', highlightthickness=0)
    cv.pack()
    window.update()
    paddle1 = paddle(cv, 'blue')
    ball1 = ball(cv, paddle1, 'red')
    
    while 1:
        
        
        if ball1.hit_bottom == False:
            ball1.draw()
            paddle1.draw()
        #---2
        if ball1.hit_bottom == True:
            if flag == True:
                del paddle1
                del ball1
                window.destroy()
                break
            if flag == False:
                window.destroy()
                
        window.update_idletasks()
        window.update()
        time.sleep(0.01)
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# Cell In[18], line 106
#     104         break
#     105     if flag == False:
# --> 106         window.destroy()
#     108 window.update_idletasks()
#     109 window.update()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\tkinter\__init__.py:2341, in Tk.destroy(self)
#    2338 """Destroy this and all descendants widgets. This will
#    2339 end the application of this Tcl interpreter."""
#    2340 for c in list(self.children.values()): c.destroy()
# -> 2341 self.tk.call('destroy', self._w)
#    2342 Misc.destroy(self)
#    2343 global _default_root
#
# TclError: can't invoke "destroy" command: application has been destroyed

# %%
#امتیاز
from tkinter import *
import time
import random
from tkinter import messagebox


flag = True

class ball:
    def __init__(self, canvas, paddle, color):
        
        self.canvas = canvas
        self.paddle = paddle
        self.id = canvas.create_oval(10,10,25,25, fill=color)
        self.canvas.move(self.id, 245, 100)
        starts = [-3,-2,-1,1,2,3]
        random.shuffle(starts)
        self.x = starts[0]
        self.y = -1
        self.height = 400
        self.width = 500
        #---
        self.var = self.canvas.create_text(20,20, text='%s' %score, 
                                    font=(None, 30))

        self.hit_bottom = False
        
    def draw(self):
        global flag
        global score
        self.canvas.move(self.id, self.x, self.y)
        
        #---
        self.canvas.itemconfig(self.var, text='%s' %score)
        
        pos = self.canvas.coords(self.id)
        if pos[1] <= 0:
            self.y = 3

        if pos[3] >= self.height:
            self.hit_bottom = True
            self.canvas.create_text(250,200, text='Game Over', 
                                    font=(None, 20))
            
            x = messagebox.askokcancel("askokcancel", "Want to continue?")
            flag = x
                
            
        if self.hit_paddle(pos) == True:
            self.y = -3   
            #---
            score += 1
        
        if pos[0] <= 0:
            self.x = 3
        if pos[2] >= self.width:
            self.x = -3

    def hit_paddle(self, pos):
        paddle_pos = self.canvas.coords(self.paddle.id)
        if pos[2] >= paddle_pos[0] and pos[0] <= paddle_pos[2]:
            if pos[3] >=paddle_pos[1] and pos[3] <= paddle_pos[3]:
                return True
        return False

class paddle():
    def __init__(self, canvas, color):
        self.canvas = canvas
        self.id = canvas.create_rectangle(0,0,100,10, fill=color)
        self.canvas.move(self.id, 200, 300)
        self.x = 0
        self.width = 500
        self.canvas.bind_all('<KeyPress-Left>', self.turn_left)
        self.canvas.bind_all('<KeyPress-Right>', self.turn_right)
        
    def draw(self):
        pos = self.canvas.coords(self.id)
        if pos[0] <= 0 and self.x < 0:
            self.x = 0
        if pos[2] >= self.width and self.x > 0:
            self.x = 0
        self.canvas.move(self.id, self.x,0)
        
    def turn_left(self, evt):
        self.x = -2
        
    def turn_right(self, evt):
        self.x = 2

while 1:
    #---
    score = 0
    window = Tk()
    window.title('Game')
    window.resizable(0,0)
    window.wm_attributes('-topmost', -1)
    cv = Canvas(window, width=500, height=400, bg='white', highlightthickness=0)
    cv.pack()
    window.update()
    
    paddle1 = paddle(cv, 'blue')
    ball1 = ball(cv, paddle1, 'red')

    while 1:  
        if ball1.hit_bottom == False:
            ball1.draw()
            paddle1.draw()

        if ball1.hit_bottom == True:
            if flag == True:
                del paddle1
                del ball1

                window.destroy()
                break
            if flag == False:
                window.destroy()
       
                    
        window.update_idletasks()
        window.update()
        time.sleep(0.01)
btn = Button(text = 'a', command=f1).pack()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# Cell In[2], line 107
#     105 while 1:
#     106     if ball1.hit_bottom == False:
# --> 107         ball1.draw()
#     108         paddle1.draw()
#     110     if ball1.hit_bottom == True:
#
# Cell In[2], line 32, in ball.draw(self)
#      30 global flag
#      31 global score
# ---> 32 self.canvas.move(self.id, self.x, self.y)
#      34 #---
#      35 self.canvas.itemconfig(self.var, text='%s' %score)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\tkinter\__init__.py:2949, in Canvas.move(self, *args)
#    2947 def move(self, *args):
#    2948     """Move an item TAGORID given in ARGS."""
# -> 2949     self.tk.call((self._w, 'move') + args)
#
# TclError: invalid command name ".!canvas"

# %%
#دوتا توپ
from tkinter import *
import time
import random
from tkinter import messagebox


flag = True

class ball:
    def __init__(self, canvas, paddle, color):
        
        self.canvas = canvas
        self.paddle = paddle
        self.id = canvas.create_oval(10,10,25,25, fill=color)
        self.canvas.move(self.id, 245, 100)
        starts = [-3,-2,-1,1,2,3]
        random.shuffle(starts)
        self.x = starts[0]
        self.y = -1
        self.height = 400
        self.width = 500
        #---
        self.var = self.canvas.create_text(20,20, text='%s' %score, 
                                    font=(None, 30))

        self.hit_bottom = False
        
    def draw(self):
        global flag
        global score
        self.canvas.move(self.id, self.x, self.y)
        
        #---
        self.canvas.itemconfig(self.var, text='%s' %score)
        
        pos = self.canvas.coords(self.id)
        if pos[1] <= 0:
            self.y = 3

        if pos[3] >= self.height:
            self.hit_bottom = True
            self.canvas.create_text(250,200, text='Game Over', 
                                    font=(None, 20))
            
            x = messagebox.askokcancel("askokcancel", "Want to continue?")
            flag = x
                
            
        if self.hit_paddle(pos) == True:
            self.y = -3   
            #---
            score += 1
        
        if pos[0] <= 0:
            self.x = 3
        if pos[2] >= self.width:
            self.x = -3

    def hit_paddle(self, pos):
        paddle_pos = self.canvas.coords(self.paddle.id)
        if pos[2] >= paddle_pos[0] and pos[0] <= paddle_pos[2]:
            if pos[3] >=paddle_pos[1] and pos[3] <= paddle_pos[3]:
                return True
        return False

class paddle():
    def __init__(self, canvas, color):
        self.canvas = canvas
        self.id = canvas.create_rectangle(0,0,100,10, fill=color)
        self.canvas.move(self.id, 200, 300)
        self.x = 0
        self.width = 500
        self.canvas.bind_all('<KeyPress-Left>', self.turn_left)
        self.canvas.bind_all('<KeyPress-Right>', self.turn_right)
        
    def draw(self):
        pos = self.canvas.coords(self.id)
        if pos[0] <= 0 and self.x < 0:
            self.x = 0
        if pos[2] >= self.width and self.x > 0:
            self.x = 0
        self.canvas.move(self.id, self.x,0)
        
    def turn_left(self, evt):
        self.x = -2
        
    def turn_right(self, evt):
        self.x = 2
fl = 0
def f1():
    global f1
    f1 = 2

while 1:
    #---
    score = 0
    window = Tk()
    window.title('Game')
    window.resizable(0,0)
    window.wm_attributes('-topmost', -1)
    cv = Canvas(window, width=500, height=400, bg='white', highlightthickness=0)
    cv.pack()
    window.update()
    
    paddle1 = paddle(cv, 'blue')
    ball1 = ball(cv, paddle1, 'red')

    q = 0
    btn = Button(window, text = 'Two ball', command=f1).pack()

    while 1:

        if f1 == 2:
            ball2 = ball(cv, paddle1, 'red')   
            q = 1
            f1 = 0
            
        if ball1.hit_bottom == False:
            if q == 1:
                ball2.draw()
            ball1.draw()
            paddle1.draw()
        if q == 1:
            if ball1.hit_bottom == True or ball2.hit_bottom == True:
                if flag == True:
                    del paddle1
                    del ball1
                    if q == 1:
                        del ball2
                    window.destroy()
                    break
                if flag == False:
                    window.destroy()
        else:
            if ball1.hit_bottom == True:
                if flag == True:
                    del paddle1
                    del ball1
                    window.destroy()
                    break
                if flag == False:
                    window.destroy()
                    
        window.update_idletasks()
        window.update()
        time.sleep(0.01)
btn = Button(text = 'a', command=f1).pack()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# Cell In[1], line 121
#     119 if ball1.hit_bottom == False:
#     120     if q == 1:
# --> 121         ball2.draw()
#     122     ball1.draw()
#     123     paddle1.draw()
#
# Cell In[1], line 32, in ball.draw(self)
#      30 global flag
#      31 global score
# ---> 32 self.canvas.move(self.id, self.x, self.y)
#      34 #---
#      35 self.canvas.itemconfig(self.var, text='%s' %score)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\tkinter\__init__.py:2949, in Canvas.move(self, *args)
#    2947 def move(self, *args):
#    2948     """Move an item TAGORID given in ARGS."""
# -> 2949     self.tk.call((self._w, 'move') + args)
#
# TclError: invalid command name ".!canvas"

# %%
#فرمول رو توضیح بدی

# %%
#BMI
ghad = float(input())
vazn = float(input())

print(vazn/(ghad*ghad))
# Out:
#  1.45
#  56
# 26.634958382877528

# %%
def f1(vazn, ghad):
    return vazn/(ghad*ghad)

ghad = float(input())
vazn = float(input())
x = f1(vazn, ghad)
print(x)
# Out:
#  1.75
#  60
# 19.591836734693878

# %%
#توضیحات فیلد هایی که نیازه
"""
Entry 
Lable
Button
""";

# %%
btn = Button(window, text='')
"""
entry = Entry(window, options)
option ---> ????
""";

# %%
import tkinter
from tkinter import *

window = Tk()
window.geometry('400x500')

entry = Entry(window, bg='red', fg='blue', bd=10, font=(None, 30)).pack()

window.mainloop()

# %%
"""
lbl = Label(window, text = "Hello Pythonteek!")
option ---> ????
""";

# %%
import tkinter
from tkinter import *

window = Tk()
window.geometry('400x500')

lbl = Label(window, text = "Hello Pythonteek!", fg='pink', bg='black', font=(None,20))
lbl.pack()

window.mainloop()

# %%
import tkinter
from tkinter import *

def Calculate():
    vazn = float(entry2.get())
    ghad = float(entry.get())
    bmi = vazn/(ghad*ghad)
    lbl3 = Label(window, text = "Your BMI is : %s" %bmi)
    lbl3.pack()

window = Tk()
window.geometry('400x500')

lbl = Label(window, text = "Height(m):")
lbl.pack()

entry = Entry(window)
entry.pack()

lbl2 = Label(window, text = "Weight(kg):")
lbl2.pack()

entry2 = Entry(window)
entry2.pack()

btn = Button(window, text='Calculate BMI', command = Calculate).pack()

window.mainloop()

# %%
# برنامه ای بنویسید که ثانیه را از کاربر با انتری بگیرد و با لیبل ساعت و دقیقه و ثانیه را نشان دهد

# %%
import tkinter
from tkinter import *

def Calculate():
    se = float(entry.get())
    hour = se//3600
    se = se%3600
    minuts = se//60
    se = se%60
    lbl3 = Label(window, text = "Hours : %s" %hour)
    lbl3.pack()
    lbl4 = Label(window, text = "Minuts : %s" %minuts)
    lbl4.pack()
    lbl5 = Label(window, text = "Seconds : %s" %se)
    lbl5.pack()

window = Tk()
window.geometry('400x500')

lbl = Label(window, text = "Enter seconds:")
lbl.pack()

entry = Entry(window)
entry.pack()

btn = Button(window, text='Calculate', command = Calculate).pack()

window.mainloop()

# %%
#ماشین حساب ضرب

# %%
import tkinter
from tkinter import *

def Calculate():
    s = entry.get()
    start = 0
    l_num = []
    l_ope = []
    for i in range(len(s)):
        if s[i] == '*':
            l_num.append(int(s[start:i]))
            start = i + 1
            l_ope.append(s[i])
        if i == len(s)-1:
            l_num.append(int(s[start:i+1]))

    sum = 1
    for i in range(len(l_num)):
        sum *= l_num[i]
    print(sum)

window = Tk()
window.geometry('400x500')

lbl = Label(window, text = "Enter:")
lbl.pack()

entry = Entry(window)
entry.pack()

btn = Button(window, text='Calculate', command = Calculate).pack()

window.mainloop()
# Out:
# 40

# %%
#Grid

# %%
import tkinter
from tkinter import *

window = Tk()
window.geometry('200x200')

btn1 = Button(window, text='001').pack()
btn2 = Button(window, text='002').pack()
btn3 = Button(window, text='003').pack()
btn4 = Button(window, text='004').pack()

window.mainloop()

# %%
import tkinter
from tkinter import *

window = Tk()
window.geometry('200x200')

btn1 = Button(window, text='001').grid(row=0, column=0)
btn2 = Button(window, text='002').grid(row=0, column=1)
btn3 = Button(window, text='003').grid(row=1, column=0)
btn4 = Button(window, text='004').grid(row=1, column=1)

window.mainloop()

# %%
#Tamrin
import tkinter
from tkinter import *

window = Tk()
window.geometry('200x200')

btn1 = Button(window, text='001').grid(row=1, column=1)
btn2 = Button(window, text='002').grid(row=1, column=2)
btn3 = Button(window, text='003').grid(row=2, column=1)
btn4 = Button(window, text='004').grid(row=3, column=1)
btn5 = Button(window, text='005').grid(row=3, column=2)
btn6 = Button(window, text='006').grid(row=3, column=3)
btn7 = Button(window, text='007').grid(row=3, column=4)
btn8 = Button(window, text='008').grid(row=4, column=2)
btn9 = Button(window, text='009').grid(row=4,column=4)

window.mainloop()

# %%
#بی ام آی رو با گرید جاشو مشخص کنیم
import tkinter
from tkinter import *

def Calculate():
    vazn = float(entry2.get())
    ghad = float(entry.get())
    bmi = vazn/(ghad*ghad)
    lbl3 = Label(window, text = "Your BMI is : %s" %bmi)
    lbl3.grid(row=4, column=1, columnspan=2)

window = Tk()
window.geometry('200x200')

lbl = Label(window, text = "Height(m):")
lbl.grid(row=1, column=1)

entry = Entry(window)
entry.grid(row=1, column=2)

lbl2 = Label(window, text = "Weight(kg):")
lbl2.grid(row=2, column=1)

entry2 = Entry(window)
entry2.grid(row=2, column=2)
btn = Button(window, text='Calculate BMI', command = Calculate).grid(row=2, column=0, columnspan=2)

window.mainloop()

# %%
import tkinter
from tkinter import *

x = 5

def Calculate():
    global x
    name = entry2.get()
    phone = entry.get()
    
    lbl5 = Label(window, text = "%s" %name)
    lbl5.grid(row=x, column=1)

    lbl6 = Label(window, text = "%s" %phone)
    lbl6.grid(row=x, column=2)
    x += 1

window = Tk()
window.geometry('400x500')

lbl = Label(window, text = "Name:")
lbl.grid(row=1, column=1, padx=10)

entry = Entry(window)
entry.grid(row=1, column=2)

lbl2 = Label(window, text = "Phone:")
lbl2.grid(row=2, column=1)

entry2 = Entry(window)
entry2.grid(row=2, column=2)

btn = Button(window, text='Calculate BMI', command = Calculate).grid(row=3, column=2)

lbl3 = Label(window, text = "Name")
lbl3.grid(row=4, column=1, padx=10)

lbl4 = Label(window, text = "Phone")
lbl4.grid(row=4, column=2, padx=10)

window.mainloop()

# %%
#1
from tkinter import *

window = Tk()
#window.title('Calculator')
window.geometry('400x500')

entry2 = Entry(window, width=30, bd=10, bg='light blue')
entry2.grid(row=0, column=0, columnspan=4)

window.mainloop()

# %%
#2
from tkinter import *

window = Tk()
window.title('Calculator')
window.geometry('400x500')

entry2 = Entry(window, width=30, bd=10, bg='light blue')
entry2.grid(row=0, column=0, columnspan=4)

#-------------------
addition = Button(window, text='+', width = 7, height = 2, command =lambda:button_click('+')).grid(row=1, column=3)
subtraction = Button(window, text='-', width = 7, height = 2, command =lambda:button_click('-')).grid(row=2, column=3)
multiply = Button(window, text='*', width = 7, height = 2, command =lambda:button_click('*')).grid(row=3, column=3)
division = Button(window, text='/', width = 7, height = 2, command =lambda:button_click('/')).grid(row=4, column=3)

window.mainloop()

#2
from tkinter import *

window = Tk()
window.title('Calculator')
window.geometry('400x500')

entry2 = Entry(window, width=30, bd=10, bg='light blue')
entry2.grid(row=0, column=0, columnspan=4)

addition = Button(window, text='+', width = 7, height = 2, command =lambda:button_click('+')).grid(row=1, column=3)
subtraction = Button(window, text='-', width = 7, height = 2, command =lambda:button_click('-')).grid(row=2, column=3)
multiply = Button(window, text='*', width = 7, height = 2, command =lambda:button_click('*')).grid(row=3, column=3)
division = Button(window, text='/', width = 7, height = 2, command =lambda:button_click('/')).grid(row=4, column=3)

#-----------------
btn7 = Button(window, text='7', width = 7, height = 2, command =lambda:button_click(7)).grid(row=1, column=0)
btn8 = Button(window, text='8', width = 7, height = 2, command =lambda:button_click(8)).grid(row=1, column=1)
btn9 = Button(window, text='9', width = 7, height = 2, command =lambda:button_click(9)).grid(row=1, column=2)

btn4 = Button(window, text='4', width = 7, height = 2, command =lambda:button_click(4)).grid(row=2, column=0)
btn5 = Button(window, text='5', width = 7, height = 2, command =lambda:button_click(5)).grid(row=2, column=1)
btn6 = Button(window, text='6', width = 7, height = 2, command =lambda:button_click(6)).grid(row=2, column=2)

btn1 = Button(window, text='1', width = 7, height = 2, command =lambda:button_click(1)).grid(row=3, column=0)
btn2 = Button(window, text='2', width = 7, height = 2, command =lambda:button_click(2)).grid(row=3, column=1)
btn3 = Button(window, text='3', width = 7, height = 2, command =lambda:button_click(3)).grid(row=3, column=2)

btn0 = Button(window, text='0', width = 7, height = 2, command =lambda:button_click(7)).grid(row=4, column=0)
window.mainloop()

# %%
#3
from tkinter import *

window = Tk()
window.title('Calculator')
window.geometry('400x500')

entry = Entry(window, width=30, bd=10, bg='light blue')
entry.grid(row=0, column=0, columnspan=4)

addition = Button(window, text='+', width = 7, height = 2, command =lambda:button_click('+')).grid(row=1, column=3)
subtraction = Button(window, text='-', width = 7, height = 2, command =lambda:button_click('-')).grid(row=2, column=3)
multiply = Button(window, text='*', width = 7, height = 2, command =lambda:button_click('*')).grid(row=3, column=3)
division = Button(window, text='/', width = 7, height = 2, command =lambda:button_click('/')).grid(row=4, column=3)


btn7 = Button(window, text='7', width = 7, height = 2, command =lambda:button_click(7)).grid(row=1, column=0)
btn8 = Button(window, text='8', width = 7, height = 2, command =lambda:button_click(8)).grid(row=1, column=1)
btn9 = Button(window, text='9', width = 7, height = 2, command =lambda:button_click(9)).grid(row=1, column=2)

btn4 = Button(window, text='4', width = 7, height = 2, command =lambda:button_click(4)).grid(row=2, column=0)
btn5 = Button(window, text='5', width = 7, height = 2, command =lambda:button_click(5)).grid(row=2, column=1)
btn6 = Button(window, text='6', width = 7, height = 2, command =lambda:button_click(6)).grid(row=2, column=2)

btn1 = Button(window, text='1', width = 7, height = 2, command =lambda:button_click(1)).grid(row=3, column=0)
btn2 = Button(window, text='2', width = 7, height = 2, command =lambda:button_click(2)).grid(row=3, column=1)
btn3 = Button(window, text='3', width = 7, height = 2, command =lambda:button_click(3)).grid(row=3, column=2)

btn0 = Button(window, text='0', width = 7, height = 2, command =lambda:button_click(7)).grid(row=4, column=0)

#--------------------
btn_clear = Button(window, text='C', width = 7, height = 2, command =button_clear).grid(row=4, column=1)
btn_equal = Button(window, text='=', width = 7, height = 2, command =button_equal).grid(row=4, column=2)

window.mainloop()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 32
#      29 btn0 = Button(window, text='0', width = 7, height = 2, command =lambda:button_click(7)).grid(row=4, column=0)
#      31 #--------------------
# ---> 32 btn_clear = Button(window, text='C', width = 7, height = 2, command =button_clear).grid(row=4, column=1)
#      33 btn_equal = Button(window, text='=', width = 7, height = 2, command =button_equal).grid(row=4, column=2)
#      35 window.mainloop()
#
# NameError: name 'button_clear' is not defined

# %%
#4
from tkinter import *

#--------------------
def button_click(number):
    entry.insert(END, str(number))

def button_clear():
    entry.delete(0, END)

def button_equal():
    ex = entry.get()
    result = eval(ex)
    entry.delete(0, END)
    entry.insert(0, result)
    
window = Tk()
window.title('Calculator')
window.geometry('230x220')

entry = Entry(window, font=(None,20), width=13, bd=10, bg='light blue')
entry.grid(row=0, column=0, columnspan=4)

addition = Button(window, text='+', width = 7, height = 2, command =lambda:button_click('+')).grid(row=1, column=3)
subtraction = Button(window, text='-', width = 7, height = 2, command =lambda:button_click('-')).grid(row=2, column=3)
multiply = Button(window, text='*', width = 7, height = 2, command =lambda:button_click('*')).grid(row=3, column=3)
division = Button(window, text='/', width = 7, height = 2, command =lambda:button_click('/')).grid(row=4, column=3)


btn7 = Button(window, text='7', width = 7, height = 2, command =lambda:button_click(7)).grid(row=1, column=0)
btn8 = Button(window, text='8', width = 7, height = 2, command =lambda:button_click(8)).grid(row=1, column=1)
btn9 = Button(window, text='9', width = 7, height = 2, command =lambda:button_click(9)).grid(row=1, column=2)

btn4 = Button(window, text='4', width = 7, height = 2, command =lambda:button_click(4)).grid(row=2, column=0)
btn5 = Button(window, text='5', width = 7, height = 2, command =lambda:button_click(5)).grid(row=2, column=1)
btn6 = Button(window, text='6', width = 7, height = 2, command =lambda:button_click(6)).grid(row=2, column=2)

btn1 = Button(window, text='1', width = 7, height = 2, command =lambda:button_click(1)).grid(row=3, column=0)
btn2 = Button(window, text='2', width = 7, height = 2, command =lambda:button_click(2)).grid(row=3, column=1)
btn3 = Button(window, text='3', width = 7, height = 2, command =lambda:button_click(3)).grid(row=3, column=2)

btn0 = Button(window, text='0', width = 7, height = 2, command =lambda:button_click(0)).grid(row=4, column=0)

btn_clear = Button(window, text='C', width = 7, height = 2, command =button_clear).grid(row=4, column=1)
btn_clear = Button(window, text='=', width = 7, height = 2, command =button_equal).grid(row=4, column=2)
window.mainloop()

# %%
import tkinter as tk
from tkinter import messagebox

# %%
import tkinter as tk
from tkinter import messagebox

game_board = [['', '', ''],
              ['', '', ''],
              ['', '', '']]

curent_player = 'X'

# %%
import tkinter as tk
from tkinter import messagebox
    
game_board = [['', '', ''],
              ['', '', ''],
              ['', '', '']]

curent_player = 'X'

def button_click(r, c):
    pass

window = tk.Tk()
window.title('X/O')

buttons = []
for row in range(3):
    row_botton = []
    for col in range(3):
        button = tk.Button(window, width=10, height=5, command=button_click(row, col))
        button.grid(row=row, column=col)
        row_botton.append(button)
        #print(row_botton)

    buttons.append(row_botton)
    #print(buttons)

window.mainloop()
# Out:
# [[<tkinter.Button object .!button>, <tkinter.Button object .!button2>, <tkinter.Button object .!button3>]]
# [[<tkinter.Button object .!button>, <tkinter.Button object .!button2>, <tkinter.Button object .!button3>], [<tkinter.Button object .!button4>, <tkinter.Button object .!button5>, <tkinter.Button object .!button6>]]
# [[<tkinter.Button object .!button>, <tkinter.Button object .!button2>, <tkinter.Button object .!button3>], [<tkinter.Button object .!button4>, <tkinter.Button object .!button5>, <tkinter.Button object .!button6>], [<tkinter.Button object .!button7>, <tkinter.Button object .!button8>, <tkinter.Button object .!button9>]]

# %%
import tkinter as tk
from tkinter import messagebox
    
game_board = [['', '', ''],
              ['', '', ''],
              ['', '', '']]

curent_player = 'X'

def button_click(r, c):
    global curent_player

    if game_board[r][c] == '':
        buttons[r][c].config(text=curent_player)
        game_board[r][c] = curent_player

    if check_winner(curent_player):
        messagebox.showinfo('Tic Tak Toe', f'player {curent_player} wins')

    elif check_tie():
        messagebox.showinfo('Tic Tak Toe', 'it\'s a tie')

    else:
        if curent_player == 'X':
            curent_player = 'O'
        else:
            curent_player = 'X'

window = tk.Tk()
window.title('Tik Tok')

buttons = []
for row in range(3):
    row_botton = []
    for col in range(3):
        button = tk.Button(window, width=10, height=5, command=lambda r = row, c = col:button_click(r, c))
        button.grid(row=row, column=col)
        row_botton.append(button)

    buttons.append(row_botton)

window.mainloop()

# %%
import tkinter as tk
from tkinter import messagebox
    
game_board = [['', '', ''],
              ['', '', ''],
              ['', '', '']]

curent_player = 'X'

def check_winner(player):
    for row in range(3):
        if game_board[row][0] == game_board[row][1] == game_board[row][2] == player:
            return True

    for col in range(3):
        if game_board[0][col] == game_board[1][col] == game_board[2][col] == player:
            return True

    if game_board[0][0] == game_board[1][1] == game_board[2][2] == player:
            return True

    if game_board[0][2] == game_board[1][1] == game_board[2][0] == player:
            return True

    return False

def button_click(r, c):
    global curent_player

    if game_board[r][c] == '':
        buttons[r][c].config(text=curent_player)
        game_board[r][c] = curent_player

    if check_winner(curent_player):
        messagebox.showinfo('Tic Tak Toe', f'player {curent_player} wins')

    elif check_tie():
        messagebox.showinfo('Tic Tak Toe', 'it\'s a tie')

    else:
        if curent_player == 'X':
            curent_player = 'O'
        else:
            curent_player = 'X'

window = tk.Tk()
window.title('Tik Tok')

buttons = []
for row in range(3):
    row_botton = []
    for col in range(3):
        button = tk.Button(window, width=10, height=5, command=lambda :button_click(row, col))
        button.grid(row=row, column=col)
        row_botton.append(button)

    buttons.append(row_botton)

window.mainloop()
# Out:
# [[<tkinter.Button object .!button>,
#   <tkinter.Button object .!button2>,
#   <tkinter.Button object .!button3>],
#  [<tkinter.Button object .!button4>,
#   <tkinter.Button object .!button5>,
#   <tkinter.Button object .!button6>],
#  [<tkinter.Button object .!button7>,
#   <tkinter.Button object .!button8>,
#   <tkinter.Button object .!button9>]]

# %%
import tkinter as tk
from tkinter import messagebox
    
game_board = [['', '', ''],
              ['', '', ''],
              ['', '', '']]

curent_player = 'X'

def check_tie():
    for row in range(3):
        for col in range(3):
            if game_board[row][col] == '':
                return False
    return True

def check_winner(player):
    for row in range(3):
        if game_board[row][0] == game_board[row][1] == game_board[row][2] == player:
            return True

    for col in range(3):
        if game_board[0][col] == game_board[1][col] == game_board[2][col] == player:
            return True

    if game_board[0][0] == game_board[1][1] == game_board[2][2] == player:
            return True

    if game_board[0][2] == game_board[1][1] == game_board[2][0] == player:
            return True

    return False

def button_click(r, c):
    global curent_player

    if game_board[r][c] == '':
        buttons[r][c].config(text=curent_player)
        game_board[r][c] = curent_player

    if check_winner(curent_player):
        messagebox.showinfo('Tic Tak Toe', f'player {curent_player} wins')

    elif check_tie():
        messagebox.showinfo('Tic Tak Toe', 'it\'s a tie')

    else:
        if curent_player == 'X':
            curent_player = 'O'
        else:
            curent_player = 'X'

window = tk.Tk()
window.title('Tik Tok')

buttons = []
for row in range(3):
    row_botton = []
    for col in range(3):
        button = tk.Button(window, width=10, height=5, command=lambda r = row, c = col:button_click(r, c))
        button.grid(row=row, column=col)
        row_botton.append(button)

    buttons.append(row_botton)

window.mainloop()

# %%
import tkinter as tk
from tkinter import messagebox
    


def check_tie():
    for row in range(3):
        for col in range(3):
            if game_board[row][col] == '':
                return False
    return True

def check_winner(player):
    for row in range(3):
        if game_board[row][0] == game_board[row][1] == game_board[row][2] == player:
            return True

    for col in range(3):
        if game_board[0][col] == game_board[1][col] == game_board[2][col] == player:
            return True

    if game_board[0][0] == game_board[1][1] == game_board[2][2] == player:
            return True

    if game_board[0][2] == game_board[1][1] == game_board[2][0] == player:
            return True

    return False

def button_click(r, c):
    global curent_player

    if game_board[r][c] == '':
        buttons[r][c].config(text=curent_player)
        game_board[r][c] = curent_player

    if check_winner(curent_player):
        messagebox.showinfo('Tic Tak Toe', f'player {curent_player} wins')

    elif check_tie():
        messagebox.showinfo('Tic Tak Toe', 'it\'s a tie')

    else:
        if curent_player == 'X':
            curent_player = 'O'
        else:
            curent_player = 'X'

def clear():
    global curent_player
    global game_board
    game_board = [['', '', ''],
                  ['', '', ''],
                  ['', '', '']]

    curent_player = 'X'
    for row in range(3):
        for col in range(3):
            buttons[row][col].config(text='')
    


window = tk.Tk()
window.title('Tik Tok')

game_board = [['', '', ''],
              ['', '', ''],
              ['', '', '']]

curent_player = 'X'
buttons = []
for row in range(3):
    row_botton = []
    for col in range(3):
        button = tk.Button(window, width=10, height=5, command=lambda r = row, c = col:button_click(r, c))
        button.grid(row=row, column=col)
        row_botton.append(button)

    buttons.append(row_botton)

btn = tk.Button(window, width=33, height=5, text='Clear', command=clear)
btn.grid(row=3, column=0, columnspan=3)
window.mainloop()

# %%
import tkinter as tk
from tkinter import ttk

window = tk.Tk()

window.geometry('400x500')

city = ['mashhad', 'tehran', 'esfehan']
citychoose = ttk.Combobox(window, width=20, values=city)
citychoose.pack()

window.mainloop()

# %%
import tkinter as tk
from tkinter import ttk

def combo():
    print(numberchoose.get())

window = tk.Tk()
window.title('Tik Tok')
window.geometry('400x500')

number = ['num1', 'num2', 'num3']
numberchoose = ttk.Combobox(window, width=20, values=number)
numberchoose.pack()

btn = Button(window, text='Press', command=combo)
btn.pack()

window.mainloop()
# Out:
# num2

# %%
import tkinter as tk
from tkinter import ttk

def combo():
    x = monthchoose.get()
    y = ???.get()
    z = ???.get()
    lbl = Label(window, text='Selected Month is: %s' %x)
    lbl.pack()

window = tk.Tk()
window.title('Tik Tok')
window.geometry('400x500')

month = ['Farvardin', 'Ordibehesht', 'Khordad', 'Tir', 'Mordad', 'Shahrivar', 'Mehr', 'Aban', 'Azar', 'Dey', 'Bahman', 'Esfand']
monthchoose = ttk.Combobox(window, width=20, values=month)
monthchoose.pack()

btn = Button(window, text='Press', command=combo)
btn.pack()


window.mainloop()

# %%
import tkinter as tk
from tkinter import ttk

def combo():
    lbl = Label(window, text='%s %s' %(studentchoose.get(), numberchoose.get()))
    lbl.pack()

window = tk.Tk()
window.title('Tik Tok')
window.geometry('400x500')

number = []
for i in range(1,21):
    number.append(i)

student = ['ali', 'mohamad', 'shahab', 'amir']

studentchoose = ttk.Combobox(window, width=20, values=student)
studentchoose.pack()

numberchoose = ttk.Combobox(window, width=20, values=number)
numberchoose.pack()



btn = Button(window, text='Press', command=combo)
btn.pack()

window.mainloop()

# %%
#تمرین و مرور آنچه در طول این مدت خوانده شده

# %%
# ????
import tkinter 
from tkinter import *
window= Tk()
counter = 0
def print_hello():
    global counter
    counter += 1
    te.config(text='count %s' %counter)
window = Tk()
window.title('python teek')
window.geometry('400x500')
te = Label(window, text='count:')
te.pack()
Button(window, text='Click Me', command=print_hello).pack()
window.mainloop()

# %%
from tkinter import *
window = Tk()

def sign():
    te.config(text='Welcome %s %s' %(first_name.get(), last_name.get()))
    
window.geometry('400x500')

Label(window, text='First Name').pack()

first_name = Entry(window)
first_name.pack()


Label(window, text='Last Name').pack()

last_name = Entry(window)
last_name.pack()


sign_in_btn = Button(window, text='sign in', command=sign)
sign_in_btn.pack()

te = Label(window, text='')
te.pack()

window.mainloop()

# %%
from tkinter import *
window = Tk()
count = 0

row = 4
def sign():
    #te.config()
    global count
    global row
    count += 1
    te = Label(window, text='%s\t%s\t%s' %(count, first_name.get(), last_name.get()))
    te.grid(row=row, column=0, columnspan=2)
    row += 1
    
window.geometry('400x500')

Label(window, text='First Name:').grid(row=0, column=0)

first_name = Entry(window)
first_name.grid(row=0, column=1)


Label(window, text='Last Name:').grid(row=1, column=0)

last_name = Entry(window)
last_name.grid(row=1, column=1)


sign_in_btn = Button(window, text='sign in', command=sign)
sign_in_btn.grid(row=2, column=0, columnspan=2)

te = Label(window, text='Number   FirstName   LastName')
te.grid(row=3, column=0, columnspan=2)
    
    
window.mainloop()

# %%
#Tamrin
from tkinter import *
window = Tk()

def Ofline():
    te.config(text='Ofline', fg='red')
def Online():
    te.config(text='Online', fg='green')
window = Tk()
window.title('python teek')
window.geometry('400x500')
te = Label(window, text='Ofline')
te.pack()
Button(window, text='Online', bd=5, command=Online).pack()
Button(window, text='Ofline', bd=5, command=Ofline).pack()
window.mainloop()

# %%
from tkinter import *

window = Tk()
window.geometry('400x500')

spin = Spinbox(window, from_ = 1, to_ = 30)
spin.pack()

window.mainloop()

# %%
from tkinter import *

window = Tk()
window.geometry('400x500')

lst = ['num1', 'num2', 'num3']

spin = Spinbox(window, values = lst)
spin.pack()

window.mainloop()

# %%
from tkinter import *

def sp():
    Label(window, text = spin.get()).pack()

window = Tk()
window.geometry('400x500')

spin = Spinbox(window, from_ = 1, to_ = 30)
spin.pack()

btn = Button(window, text='Press', command=sp)
btn.pack()

window.mainloop()

# %%
from tkinter import *

def sp():
    Label(window, text = '%s\t%s\t%s' %(spin1.get(), spin2.get(), spin3.get())).grid(row=4, column=0, columnspan=3)

window = Tk()
window.geometry('400x500')

year = []
for i in range(1350,1404):
    year.append(i)

month = ['Farvardin', 'Ordibehesht', 'Khordad', 'Tir', 'Mordad', 'Shahrivar', 'Mehr', 'Aban', 'Azar', 'Dey', 'Bahman', 'Esfand']

day = []
for i in range(1,31):
    day.append(i)

lbl = Label(window, text = 'Year:')
lbl.grid(row=0, column=0)

spin1 = Spinbox(window, values = year)
spin1.grid(row=0, column=1)

lbl = Label(window, text = 'Month:')
lbl.grid(row=1, column=0)

spin2 = Spinbox(window, values = month)
spin2.grid(row=1, column=1)

lbl = Label(window, text = 'Day:')
lbl.grid(row=2, column=0)

spin3 = Spinbox(window, values = day)
spin3.grid(row=2, column=1)

btn = Button(window, text='Press', command=sp)
btn.grid(row=3, column=0, columnspan=2)

window.mainloop()

# %%
# Checkbutton
from tkinter import *
window = Tk()
window.title('python teek')

Checkbutton(window, text='Male').pack()
Checkbutton(window, text='Famale').pack()

window.mainloop()

# %%
# get in Chackbutton
from tkinter import *
window = Tk()
window.title('python teek')
window.geometry('400x500')

def state():
    if  male_var.get() == 1:
        print('male')
    elif famale_var.get() == 1:
        print('famale')
    else :
        print('Nothing')

male_var = IntVar()
famale_var = IntVar()
Checkbutton(window, text='Male', variable=male_var).pack()
Checkbutton(window, text='Famale', variable=famale_var).pack()

bt = Button(window, text='male/famale', command=state)
bt.pack()

window.mainloop()
# Out:
# male

# %%
from tkinter import *
window = Tk()
window.title('python teek')
window.geometry('400x500')

def state():
    if  male_var.get() == 1:
        te.config(text='Male')
    elif famale_var.get() == 1:
        te.config(text='Famale')
    else :
        te.config(text='Nothing')

male_var = IntVar()
famale_var = IntVar()
Checkbutton(window, text='You are Male', variable=male_var).pack()
Checkbutton(window, text='You are Famale', variable=famale_var).pack()

bt = Button(window, text='male/famale', command=state)
bt.pack()

te = Label(window, text='')
te.pack()

window.mainloop()

# %%
#Radiobutton
from tkinter import *
window = Tk()
window.title('python teek')
window.geometry('400x400')

v = IntVar()
Radiobutton(window, text='One', variable = v).pack()

window.mainloop()

# %%
from tkinter import *
window = Tk()
window.title('python teek')
window.geometry('400x400')

Mode = [('male', 'male'), ('female', 'female'), ('kid', 'kid')]
v = StringVar()
v.set('male')

for text, mode in Mode:
    b = Radiobutton(window, text=text, variable = v, value=mode)
    b.pack()
    
window.mainloop()

# %%
from tkinter import *

def state():
    if  v.get() == 'male':
        te.config(text='Male')
    elif v.get() == 'female':
        te.config(text='Famale')
    else :
        te.config(text='Nothing')

window = Tk()
window.title('python teek')
window.geometry('400x400')

Mode = [('male', 'male'), ('female', 'female'), ('kid', 'kid')]
v = StringVar()
v.set('male')

for text, mode in Mode:
    b = Radiobutton(window, text=text, variable = v, value=mode)
    b.pack()

bt = Button(window, text='male/famale', command=state)
bt.pack()

te = Label(window, text='')
te.pack()

window.mainloop()

# %%
import tkinter
from tkinter import *
from tkinter import ttk

#ذخیره سازی
def Saving():
    f = open('info.txt', 'w')
    f.write('First Name: %s' %entry1.get())
    f.write('\nLast Name: %s' %entry2.get())
    f.write('\nBirthday: %s/%s/%s' %(spin1.get(), spin2.get(), spin3.get()))
    f.write('\nGender: %s' %v.get())
    f.write('\nPhoneNumber: %s' %entry3.get())
    f.write('\nLanguage:\t')
    if python.get() == 1:
        f.write('Python\t')
    if c.get() == 1:
        f.write('C++\t')
    if java.get() == 1:
        f.write('Java\t')

#read
def read():
    f = open('info.txt', 'r')
    lst = f.readlines()
    print(lst[0])
    print(lst[1])
    print(lst[2])
    print(lst[3])
    print(lst[4])
    print(lst[5])


window = Tk()
window.geometry('700x400')

# اسم و فامیل
lbl1 = Label(window, text = "First Name: ")
lbl1.grid(row=0, column=0)
entry1 = Entry(window)
entry1.grid(row=0, column=1)

lbl2 = Label(window, text = "Last Name: ")
lbl2.grid(row=0, column=2)
entry2 = Entry(window)
entry2.grid(row=0, column=3)

#تاریخ تولد
year = []
for i in range(1350,1404):
    year.append(i)

month = ['Farvardin', 'Ordibehesht', 'Khordad', 'Tir', 'Mordad', 'Shahrivar', 'Mehr', 'Aban', 'Azar', 'Dey', 'Bahman', 'Esfand']

day = []
for i in range(1,31):
    day.append(i)

lbl3 = Label(window, text = 'Year: ')
lbl3.grid(row=1, column=0)

spin1 = ttk.Combobox(window, values = year)
spin1.grid(row=1, column=1)

lbl4 = Label(window, text = 'Month: ')
lbl4.grid(row=1, column=2)

spin2 = ttk.Combobox(window, values = month)
spin2.grid(row=1, column=3)

lbl5 = Label(window, text = 'Day: ')
lbl5.grid(row=1, column=4)

spin3 = ttk.Combobox(window, values = day)
spin3.grid(row=1, column=5)

#جنسیت
lbl6 = Label(window, text = 'Gender: ')
lbl6.grid(row=2, column=0)
Mode = [('Male', 'Male'), ('Female', 'Female'), ('Kid', 'Kid')]
v = StringVar()
v.set('male')

counter = 1
for text, mode in Mode:
    b = Radiobutton(window, text=text, variable = v, value=mode)
    b.grid(row=2, column=counter)
    counter += 1

#شماره تلفن
lbl7 = Label(window, text = "Phone Number: ")
lbl7.grid(row=3, column=0)
entry3 = Entry(window)
entry3.grid(row=3, column=1)


#زبان های برنامه نویسی
lbl8 = Label(window, text = "Language: ")
lbl8.grid(row=4, column=0)
python = IntVar()
c = IntVar()
java = IntVar()
Checkbutton(window, text='Python', variable=python).grid(row=4, column=1)
Checkbutton(window, text='C++', variable=c).grid(row=4, column=2)
Checkbutton(window, text='Java', variable=java).grid(row=4, column=3)

#دکمه
bt = Button(window, text='Saving', command=Saving)
bt.grid(row=5, column=0)

bt = Button(window, text='Loading', command=read)
bt.grid(row=5, column=1)

window.mainloop()

# %%
# Menu
from tkinter import *
window = Tk()
window.geometry('400x500')

def Hello():
    print('Hello')

menu_bar = Menu(window)
menu_bar.add_command(label='Hello', command=Hello)

window.config(menu=menu_bar)

window.mainloop()
# Out:
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello

# %%
from tkinter import *
window = Tk()
window.geometry('400x500')

def Hello():
    print('Hello')

menu_bar = Menu(window, tearoff=0)

filemenu = Menu(menu_bar)
menu_bar.add_cascade(label='File', menu=filemenu)
menu_bar.add_command(label='File2')

filemenu.add_command(label='Open')
filemenu.add_command(label='Save')
filemenu.add_command(label='Exit')

window.config(menu=menu_bar)

window.mainloop()

# %%
from tkinter import *
window = Tk()
window.geometry('400x500')

def Hello():
    print('Hello')

menu_bar = Menu(window, tearoff=0)

filemenu = Menu(menu_bar)

sa = Menu(filemenu, tearoff=0)
menu_bar.add_cascade(label='File', menu=filemenu)

filemenu.add_command(label='Open')
filemenu.add_cascade(label='Save', menu=sa)
filemenu.add_command(label='Exit')

sa.add_command(label='22')

window.config(menu=menu_bar)

window.mainloop()

# %%
import tkinter
from tkinter import *
from tkinter import ttk

#ذخیره سازی
def Saving():
    f = open('info.txt', 'w')
    f.write('First Name: %s' %entry1.get())
    f.write('\nLast Name: %s' %entry2.get())
    f.write('\nBirthday: %s/%s/%s' %(spin1.get(), spin2.get(), spin3.get()))
    f.write('\nGender: %s' %v.get())
    f.write('\nPhoneNumber: %s' %entry3.get())
    f.write('\nLanguage:\t')
    if python.get() == 1:
        f.write('Python\t')
    if c.get() == 1:
        f.write('C++\t')
    if java.get() == 1:
        f.write('Java\t')

#read
def read():
    f = open('info.txt', 'r')
    lst = f.readlines()
    for i in lst:
        print(i)

#append
def Appe():
    f = open('info.txt', 'a')
    f.write('\n')
    f.write('First Name: %s' %entry1.get())
    f.write('\nLast Name: %s' %entry2.get())
    f.write('\nBirthday: %s/%s/%s' %(spin1.get(), spin2.get(), spin3.get()))
    f.write('\nGender: %s' %v.get())
    f.write('\nPhoneNumber: %s' %entry3.get())
    f.write('\nLanguage:\t')
    if python.get() == 1:
        f.write('Python\t')
    if c.get() == 1:
        f.write('C++\t')
    if java.get() == 1:
        f.write('Java\t')


window = Tk()
window.geometry('700x400')

# اسم و فامیل
lbl1 = Label(window, text = "First Name: ")
lbl1.grid(row=0, column=0)
entry1 = Entry(window)
entry1.grid(row=0, column=1)

lbl2 = Label(window, text = "Last Name: ")
lbl2.grid(row=0, column=2)
entry2 = Entry(window)
entry2.grid(row=0, column=3)

#تاریخ تولد
year = []
for i in range(1350,1404):
    year.append(i)

month = ['Farvardin', 'Ordibehesht', 'Khordad', 'Tir', 'Mordad', 'Shahrivar', 'Mehr', 'Aban', 'Azar', 'Dey', 'Bahman', 'Esfand']

day = []
for i in range(1,31):
    day.append(i)

lbl3 = Label(window, text = 'Year: ')
lbl3.grid(row=1, column=0)

spin1 = ttk.Combobox(window, values = year)
spin1.grid(row=1, column=1)

lbl4 = Label(window, text = 'Month: ')
lbl4.grid(row=1, column=2)

spin2 = ttk.Combobox(window, values = month)
spin2.grid(row=1, column=3)

lbl5 = Label(window, text = 'Day: ')
lbl5.grid(row=1, column=4)

spin3 = ttk.Combobox(window, values = day)
spin3.grid(row=1, column=5)

#جنسیت
lbl6 = Label(window, text = 'Gender: ')
lbl6.grid(row=2, column=0)
Mode = [('Male', 'Male'), ('Female', 'Female'), ('Kid', 'Kid')]
v = StringVar()
v.set('male')

counter = 1
for text, mode in Mode:
    b = Radiobutton(window, text=text, variable = v, value=mode)
    b.grid(row=2, column=counter)
    counter += 1

#شماره تلفن
lbl7 = Label(window, text = "Phone Number: ")
lbl7.grid(row=3, column=0)
entry3 = Entry(window)
entry3.grid(row=3, column=1)


#زبان های برنامه نویسی
lbl8 = Label(window, text = "Language: ")
lbl8.grid(row=4, column=0)
python = IntVar()
c = IntVar()
java = IntVar()
Checkbutton(window, text='Python', variable=python).grid(row=4, column=1)
Checkbutton(window, text='C++', variable=c).grid(row=4, column=2)
Checkbutton(window, text='Java', variable=java).grid(row=4, column=3)

#دکمه
bt = Button(window, text='Saving', command=Saving)
bt.grid(row=5, column=0)

bt = Button(window, text='Loading', command=read)
bt.grid(row=5, column=1)

menu_bar = Menu(window, tearoff=0)

filemenu = Menu(menu_bar)
menu_bar.add_cascade(label='File', menu=filemenu)

filemenu.add_command(label='Open', command=read)
filemenu.add_command(label='Save', command=Saving)
filemenu.add_command(label='Append', command=Appe)

window.config(menu=menu_bar)

window.mainloop()

# %%
from tkinter import *
window = Tk()
window.geometry('400x500')

list_box = Listbox(window)
list_box.pack()

window.mainloop()

# %%
from tkinter import *
window = Tk()
window.geometry('400x500')

list_box = Listbox(window)
list_box.pack()

list_box.insert(1, 'Python')
list_box.insert(2, 'C++')

window.mainloop()

# %%
from tkinter import *
window = Tk()
window.geometry('400x500')

list_box = Listbox(window)
list_box.pack()

list_box.insert(1, 'Python')
list_box.insert(2, 'C++')
list_box.insert(END, 'Java')
window.mainloop()

# %%
# Listbox -> insert
from tkinter import *
window = Tk()
#window.geometry('400x500')

def name():
    list_box.insert(END, entry.get())

entry = Entry(window, width=40)
entry.pack()

bt = Button(window, text='add name', command=name)
bt.pack()

list_box = Listbox(window, width=40)
list_box.pack()

window.mainloop()

# %%
# Listbox -> delete
from tkinter import *
window = Tk()
window.geometry('400x500')

def name():
    list_box.insert(END, entry.get())

def clear():
    list_box.delete(0,END)
    
entry = Entry(window)
entry.pack()

bt = Button(window, text='add name', command=name)
bt.pack()
bt2 = Button(window, text='clear', command=clear)
bt2.pack()

list_box = Listbox(window)
list_box.pack()

window.mainloop()

# %%
# Scorllbar
from tkinter import *
window = Tk()
window.geometry('400x500')

scroll = Scrollbar(window)
scroll.pack(side=RIGHT, fill=BOTH)

list_box = Listbox(window)
list_box.pack(expand=True, fill=BOTH)

for i in range(100):
    list_box.insert(END, 'Number:%s' %i)

list_box.config(yscrollcommand = scroll.set)
scroll.config(command=list_box.yview)

window.mainloop()

# %%
from tkinter import *
window = Tk()
#window.geometry('400x500')

def f1():
    i = entry.get()
    list_box.insert(END, '%s' %i)

def f2():
    list_box.delete(END,END)

scroll = Scrollbar(window)
scroll.pack(side=RIGHT, fill=BOTH)

list_box = Listbox(window)
list_box.pack(expand=True, fill=BOTH)

list_box.config(yscrollcommand = scroll.set)
scroll.config(command=list_box.yview)

entry = Entry(window, width=40, font=(None, 10))
entry.pack()

btn = Button(window,  text='Add Task', command=f1)
btn.pack()

btn2 = Button(window,  text='Delete Task', command=f2)
btn2.pack()

window.mainloop()

# %%
#Github

# %%
# Labelframe
from tkinter import *
window = Tk()
window.geometry('400x500')

frame1 = LabelFrame(window, bg='red', text='Frame1')
frame1.pack(fill='both', expand=True)

frame2 = LabelFrame(window, bg='blue', text='Frame1')
frame2.pack(fill='both', expand=True)

Label(frame1, text='Frame1').pack()
Label(frame2, text='Frame2').pack()


window.mainloop()

# %%
# Labelframe
from tkinter import *

def f1():
    i = entry.get()
    list_box.insert(END, '%s' %i)

def f2():
    list_box.delete(END,END)
    
window = Tk()
window.geometry('400x500')

frame1 = LabelFrame(window, bg='red', text='Frame1')
frame1.pack(fill='both', expand=True)

frame2 = LabelFrame(window, bg='blue', text='Frame1')
frame2.pack(fill='both', expand=True)

Label(frame1, text='Field Name:').pack()
entry = Entry(frame1, width=40, font=(None, 10))
entry.pack()
btn = Button(frame1,  text='Add Task', command=f1)
btn.pack()
btn2 = Button(frame1,  text='Delete Task', command=f2)
btn2.pack()

Label(frame2, text='List Name:').pack()
scroll = Scrollbar(frame2)
scroll.pack(side=RIGHT, fill=BOTH)

list_box = Listbox(frame2)
list_box.pack(expand=True, fill=BOTH)

list_box.config(yscrollcommand = scroll.set)
scroll.config(command=list_box.yview)

window.mainloop()

# %%
# Labelframe
from tkinter import *
window = Tk()
window.geometry('400x500')

panel = PanedWindow(window, bg='red', bd=5)
panel.pack(fill = 'both', expand=True)

la = Label(panel, text='Panel1')
panel.add(la)
window.mainloop()

# %%
# Labelframe
from tkinter import *
window = Tk()
window.geometry('400x500')

panel = PanedWindow(window, bg='red', bd=4)
panel.pack(fill = 'both', expand=True)

la = Label(panel, text='Panel1')
panel.add(la)

la = Button(panel, text='Panel2', bg='green')
la2 = Button(panel, text='Panel3', bg='blue')
panel.add(la)
panel.add(la2)
window.mainloop()

# %%
# Labelframe
from tkinter import *
window = Tk()
window.geometry('400x500')

panel = PanedWindow(window, bg='red', bd=4, orient=VERTICAL)
panel.pack(fill = 'both', expand=True)

la = Label(panel, text='Panel1')
panel.add(la)

panel2 = PanedWindow(panel, bg='blue', bd=4)
panel.add(panel2)

la1 = Label(panel, text='Panel2_1')
panel2.add(la1)

la1 = Label(panel, text='Panel2_2')
panel2.add(la1)

window.mainloop()

# %%
# Labelframe
from tkinter import *
window = Tk()
window.geometry('400x500')

panel = PanedWindow(window, bg='red', bd=4, orient=VERTICAL)
panel.pack(fill = 'both', expand=True)

la = Label(panel, text='Panel1')
panel.add(la)

panel2 = PanedWindow(panel, bg='blue', bd=4 , orient=VERTICAL)
panel.add(panel2)

la1 = Label(panel2, text='Panel2_1')
panel2.add(la1)

la1 = Label(panel2, text='Panel2_2')
panel2.add(la1)

panel3 = PanedWindow(panel, bg='green', bd=4)
panel.add(panel3)

la1 = Label(panel3, text='Panel3-1')
panel3.add(la1)

la1 = Label(panel3, text='Panel3-2')
panel3.add(la1)

la1 = Label(panel3, text='Panel3-3')
panel3.add(la1)

window.mainloop()
